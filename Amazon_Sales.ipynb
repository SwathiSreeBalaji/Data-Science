# %%
from google.colab import files
uploaded=files.upload()

# %%
import pandas as pd
import numpy as np
df=pd.read_excel('/content/Amazon Sale.xlsx') #read excel file
df
df.head(10) #first row
df.tail(10) #last row
df.loc[0:10,'product_id':'discounted_price']
df['rating']
new=df.fillna("TBD")
new
row_count = len(df)
print(row_count)
print(df.shape) # Display the first few rows and shape of the DataFrame
# Out:
#     product_id                                       product_name  \
# 0   B07JW9H4J1                                                TBD
# 1          TBD                                                TBD
# 2   B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3          TBD                                                TBD
# 4          TBD  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# 5   B08Y1TFSP6                                                TBD
# 6          TBD                                                TBD
# 7   B08DDRGWTJ                                                TBD
# 8   B008IFXQFU                                                TBD
# 9   B082LZGK39  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 10         TBD  Portronics Konnect L POR-1081 Fast Charging 3A...
# 11  B0789LZTCJ                                                TBD
# 12  B07KSMBL2H  AmazonBasics Flexible Premium HDMI Cable (Blac...
# ...
